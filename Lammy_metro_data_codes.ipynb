# %% [markdown]
# <a href="https://colab.research.google.com/github/LammyG/LammyG/blob/main/Lammy_metro_data_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-46967e99-b6bb-46a5-9406-f6ea04ee4705" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46967e99-b6bb-46a5-9406-f6ea04ee4705">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving metro_data.csv to metro_data.csv

# %%
import numpy as np
import pandas as pd
import io

# %%
metro_data = pd.read_csv('metro_data.csv')

# %%
metro_data.head()
# Out:
#    land_area  percent_city  percent_senior  ...  income  region  crime_rate
# 0       1384          78.1            12.3  ...   72100       1       75.55
# 1       3719          43.9             9.4  ...   54542       2       56.03
# 2       3553          37.4            10.7  ...   33216       1       41.32
# 3       3916          29.9             8.8  ...   32906       2       67.38
# 4       2480          31.5            10.5  ...   26573       4       80.19
#
# [5 rows x 10 columns]

# %%
metro_data.describe()
# Out:
#           land_area  percent_city  ...     region  crime_rate
# count     99.000000     99.000000  ...  99.000000   99.000000
# mean    2615.727273     42.518182  ...   2.494949   55.643030
# std     3045.826210     17.348277  ...   1.013921   13.470943
# min       47.000000     13.400000  ...   1.000000   23.320000
# 25%     1408.000000     30.100000  ...   2.000000   46.115000
# 50%     1951.000000     39.500000  ...   3.000000   56.060000
# 75%     2890.500000     52.600000  ...   3.000000   63.860000
# max    27293.000000    100.000000  ...   4.000000   85.620000
#
# [8 rows x 10 columns]

# %%
 metro_data.mean()
# Out:
# land_area         2615.727273
# percent_city        42.518182
# percent_senior       9.781818
# physicians        1828.333333
# hospital_beds     6345.868687
# graduates           54.463636
# work_force         449.366667
# income            6762.505051
# region               2.494949
# crime_rate          55.643030
# dtype: float64

# %%
metro_data.mode()
# Out:
#     land_area  percent_city  percent_senior  ...  income  region  crime_rate
# 0       813.0          13.4            10.5  ...     769     3.0       70.66
# 1      1758.0          19.5             NaN  ...    1148     NaN         NaN
# 2         NaN          19.9             NaN  ...    1337     NaN         NaN
# 3         NaN          28.4             NaN  ...    1354     NaN         NaN
# 4         NaN          31.5             NaN  ...    1386     NaN         NaN
# ..        ...           ...             ...  ...     ...     ...         ...
# 94        NaN           NaN             NaN  ...   26573     NaN         NaN
# 95        NaN           NaN             NaN  ...   32906     NaN         NaN
# 96        NaN           NaN             NaN  ...   33216     NaN         NaN
# 97        NaN           NaN             NaN  ...   54542     NaN         NaN
# 98        NaN           NaN             NaN  ...   72100     NaN         NaN
#
# [99 rows x 10 columns]

# %%
metro_data.isnull()
# Out:
#     land_area  percent_city  percent_senior  ...  income  region  crime_rate
# 0       False         False           False  ...   False   False       False
# 1       False         False           False  ...   False   False       False
# 2       False         False           False  ...   False   False       False
# 3       False         False           False  ...   False   False       False
# 4       False         False           False  ...   False   False       False
# ..        ...           ...             ...  ...     ...     ...         ...
# 94      False         False           False  ...   False   False       False
# 95      False         False           False  ...   False   False       False
# 96      False         False           False  ...   False   False       False
# 97      False         False           False  ...   False   False       False
# 98      False         False           False  ...   False   False       False
#
# [99 rows x 10 columns]

# %%
metro_data.isnull().sum()
# Out:
# land_area         0
# percent_city      0
# percent_senior    0
# physicians        0
# hospital_beds     0
# graduates         0
# work_force        0
# income            0
# region            0
# crime_rate        0
# dtype: int64

# %%
metro_data.notnull()
# Out:
#     land_area  percent_city  percent_senior  ...  income  region  crime_rate
# 0        True          True            True  ...    True    True        True
# 1        True          True            True  ...    True    True        True
# 2        True          True            True  ...    True    True        True
# 3        True          True            True  ...    True    True        True
# 4        True          True            True  ...    True    True        True
# ..        ...           ...             ...  ...     ...     ...         ...
# 94       True          True            True  ...    True    True        True
# 95       True          True            True  ...    True    True        True
# 96       True          True            True  ...    True    True        True
# 97       True          True            True  ...    True    True        True
# 98       True          True            True  ...    True    True        True
#
# [99 rows x 10 columns]

# %%
metro_data.groupby(['income']).count()
# Out:
#         land_area  percent_city  percent_senior  ...  work_force  region  crime_rate
# income                                           ...
# 769             1             1               1  ...           1       1           1
# 1148            1             1               1  ...           1       1           1
# 1337            1             1               1  ...           1       1           1
# 1354            1             1               1  ...           1       1           1
# 1386            1             1               1  ...           1       1           1
# ...           ...           ...             ...  ...         ...     ...         ...
# 26573           1             1               1  ...           1       1           1
# 32906           1             1               1  ...           1       1           1
# 33216           1             1               1  ...           1       1           1
# ...

# %%
metro_data.count()
# Out:
# land_area         99
# percent_city      99
# percent_senior    99
# physicians        99
# hospital_beds     99
# graduates         99
# work_force        99
# income            99
# region            99
# crime_rate        99
# dtype: int64

# %%
metro_df1 = metro_data.iloc[1:50].reset_index(drop=True)
metro_df2 = metro_data.iloc[1:50].reset_index(drop=True)

# %%
metro_df1
# Out:
#     land_area  percent_city  percent_senior  ...  income  region  crime_rate
# 0        3719          43.9             9.4  ...   54542       2       56.03
# 1        3553          37.4            10.7  ...   33216       1       41.32
# 2        3916          29.9             8.8  ...   32906       2       67.38
# 3        2480          31.5            10.5  ...   26573       4       80.19
# 4        2815          23.1             6.7  ...   25663       3       58.48
# 5        8360          46.3             8.2  ...   18350       3       72.25
# 6        6794          60.1             6.3  ...   18221       3       64.88
# 7        3049          19.5            12.1  ...   15826       1       30.51
# 8        4647          31.5             9.2  ...   14542       2       55.30
# 9        1008          16.6            10.3  ...   15953       1       54.16
# 10       1519          31.8            10.5  ...   14684       2       52.73
# ...

# %%
metro_df2
# Out:
#     land_area  percent_city  percent_senior  ...  income  region  crime_rate
# 0        3719          43.9             9.4  ...   54542       2       56.03
# 1        3553          37.4            10.7  ...   33216       1       41.32
# 2        3916          29.9             8.8  ...   32906       2       67.38
# 3        2480          31.5            10.5  ...   26573       4       80.19
# 4        2815          23.1             6.7  ...   25663       3       58.48
# 5        8360          46.3             8.2  ...   18350       3       72.25
# 6        6794          60.1             6.3  ...   18221       3       64.88
# 7        3049          19.5            12.1  ...   15826       1       30.51
# 8        4647          31.5             9.2  ...   14542       2       55.30
# 9        1008          16.6            10.3  ...   15953       1       54.16
# 10       1519          31.8            10.5  ...   14684       2       52.73
# ...

# %%
pd.merge(metro_df1, metro_df2, how="inner")
# Out:
#     land_area  percent_city  percent_senior  ...  income  region  crime_rate
# 0        3719          43.9             9.4  ...   54542       2       56.03
# 1        3553          37.4            10.7  ...   33216       1       41.32
# 2        3916          29.9             8.8  ...   32906       2       67.38
# 3        2480          31.5            10.5  ...   26573       4       80.19
# 4        2815          23.1             6.7  ...   25663       3       58.48
# 5        8360          46.3             8.2  ...   18350       3       72.25
# 6        6794          60.1             6.3  ...   18221       3       64.88
# 7        3049          19.5            12.1  ...   15826       1       30.51
# 8        4647          31.5             9.2  ...   14542       2       55.30
# 9        1008          16.6            10.3  ...   15953       1       54.16
# 10       1519          31.8            10.5  ...   14684       2       52.73
# ...

# %%
pd.merge(metro_df1, metro_df2,how="outer")
# Out:
#     land_area  percent_city  percent_senior  ...  income  region  crime_rate
# 0        3719          43.9             9.4  ...   54542       2       56.03
# 1        3553          37.4            10.7  ...   33216       1       41.32
# 2        3916          29.9             8.8  ...   32906       2       67.38
# 3        2480          31.5            10.5  ...   26573       4       80.19
# 4        2815          23.1             6.7  ...   25663       3       58.48
# 5        8360          46.3             8.2  ...   18350       3       72.25
# 6        6794          60.1             6.3  ...   18221       3       64.88
# 7        3049          19.5            12.1  ...   15826       1       30.51
# 8        4647          31.5             9.2  ...   14542       2       55.30
# 9        1008          16.6            10.3  ...   15953       1       54.16
# 10       1519          31.8            10.5  ...   14684       2       52.73
# ...

# %%
pd.merge(metro_df1, metro_df2, how="left")
# Out:
#     land_area  percent_city  percent_senior  ...  income  region  crime_rate
# 0        3719          43.9             9.4  ...   54542       2       56.03
# 1        3553          37.4            10.7  ...   33216       1       41.32
# 2        3916          29.9             8.8  ...   32906       2       67.38
# 3        2480          31.5            10.5  ...   26573       4       80.19
# 4        2815          23.1             6.7  ...   25663       3       58.48
# 5        8360          46.3             8.2  ...   18350       3       72.25
# 6        6794          60.1             6.3  ...   18221       3       64.88
# 7        3049          19.5            12.1  ...   15826       1       30.51
# 8        4647          31.5             9.2  ...   14542       2       55.30
# 9        1008          16.6            10.3  ...   15953       1       54.16
# 10       1519          31.8            10.5  ...   14684       2       52.73
# ...
